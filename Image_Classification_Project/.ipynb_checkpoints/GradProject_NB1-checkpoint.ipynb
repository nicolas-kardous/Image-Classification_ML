# %% [markdown]
# <h1> DS200A Computer Vision Assignment</h1>

# %% [markdown]
# <h2>  Part One: Data Input </h2>

# %% [markdown]
# <h3>  Import Statements </h3>

# %%
#Import anything you need here
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import skimage
from skimage import data
from skimage import io
import os

# %%
#Example of reading in a file


filename = os.path.join(skimage.data_dir, 'd.jpg')
dog = io.imread(filename)
skimage.io.imshow(dog)

plt.show()
filename2 = os.path.join(skimage.data_dir, 'c.jpg')
cat = io.imread(filename2)
example_data_frame= pd.DataFrame()


example_data_frame['Pictures']=[dog, cat]
example_data_frame['Encoding']=[1,2]
example_data_frame
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7b2c10e02818> in <module>
#       3
#       4 filename = os.path.join(skimage.data_dir, 'd.jpg')
# ----> 5 dog = io.imread(filename)
#       6 skimage.io.imshow(dog)
#       7
#
# ~/opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, flatten, **plugin_args)
#      59
#      60     with file_or_url_context(fname) as fname:
# ---> 61         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      62
#      63     if not hasattr(img, 'ndim'):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     208                                (plugin, kind))
#     209
# --> 210     return func(*args, **kwargs)
#     211
#     212
#
# ~/opt/anaconda3/lib/python3.7/site-packages/imageio/core/functions.py in imread(uri, format, **kwargs)
#     262
#     263     # Get reader and read first
# --> 264     reader = read(uri, format, "i", **kwargs)
#     265     with reader:
#     266         return reader.get_data(0)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/imageio/core/functions.py in get_reader(uri, format, mode, **kwargs)
#     171
#     172     # Create request object
# --> 173     request = Request(uri, "r" + mode, **kwargs)
#     174
#     175     # Get format
#
# ~/opt/anaconda3/lib/python3.7/site-packages/imageio/core/request.py in __init__(self, uri, mode, **kwargs)
#     124
#     125         # Parse what was given
# --> 126         self._parse_uri(uri)
#     127
#     128         # Set extension
#
# ~/opt/anaconda3/lib/python3.7/site-packages/imageio/core/request.py in _parse_uri(self, uri)
#     276                 # Reading: check that the file exists (but is allowed a dir)
#     277                 if not os.path.exists(fn):
# --> 278                     raise FileNotFoundError("No such file: '%s'" % fn)
#     279             else:
#     280                 # Writing: check that the directory to write to does exist
#
# FileNotFoundError: No such file: '/Users/nicolaskardous/opt/anaconda3/lib/python3.7/site-packages/skimage/data/d.jpg'

# %% [markdown]
# <h4> Using the code for reference, take the given folder and create a dataframe with the picture object, and the encoding as listed below. </h4>
# 0=Airplanes, 1=Bear, 2=Blimp, 3=Comet, 4=Crab, 5=Dog, 6=Dolphin, 7=Giraffe, 8=Goat, 9=Gorilla, 10=Kangaroo, 11=Killer-Whale, 12=Leopards, 13=Llama, 14= Penguin, 15= Porcupine, 16=Teddy-Bear, 17=Triceratops, 18=Unicorn, 19=Zebra

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-d5df0069828e> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
# #unzip folder
# import zipfile
# with zipfile.ZipFile("drive/My Drive/D100_Final_Project/20_categories_training.zip", 'r') as zip_ref:
#     zip_ref.extractall("drive/My Drive/D100_Final_Project/")

# %%
# #unzip folder
# import zipfile
# with zipfile.ZipFile("drive/My Drive/D100_Final_Project/20_Validation.zip", 'r') as zip_ref:
#     zip_ref.extractall("drive/My Drive/D100_Final_Project/")

# %%
def read_organize_data():
    #Fill this function out, should return a dataframe with picture object, and correct encoding
    #SOURCE:
    #https://stackoverflow.com/questions/15312953/choose-a-file-starting-with-a-given-string
    #https://stackoverflow.com/questions/28339000/unzip-zip-files-in-folders-and-subfolders-with-python/30591949
    #https://stackoverflow.com/questions/36285502/how-to-extract-zip-file-recursively-in-python

    
    file_path = os.path.join(os.getcwd(), 'drive/My Drive/D100_Final_Project/20_categories_training')
    
    df = pd.DataFrame(columns=['image', 'label'])
    folders = os.listdir(file_path)
    folders.sort()

    i = 0
    for file_name in folders: #for each subfolder
        if file_name.startswith('.'): #image name format ._
            continue
        print(file_name) #checkpoint

        for image_file in os.listdir(os.path.join(file_path, file_name)):
            if image_file.startswith('.'):
                continue
            image_file = os.path.join(file_path, file_name, image_file)
            image = io.imread(image_file)
            # skimage.io.imshow(image)
            # plt.show()
            df = df.append({'image': image, 'label': i}, ignore_index=True)
        i += 1
    return df

# filename = os.path.join(skimage.data_dir, 'd.jpg')
# dog = io.imread(filename)
# skimage.io.imshow(dog)

# plt.show()
# filename2 = os.path.join(skimage.data_dir, 'c.jpg')
# cat = io.imread(filename2)
# example_data_frame= pd.DataFrame()


# example_data_frame['Pictures']=[dog, cat]
# example_data_frame['Encoding']=[1,2]
# example_data_frame

# %%
starting_data = read_organize_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-73dfdb8e3969> in <module>
# ----> 1 starting_data = read_organize_data()
#
# <ipython-input-5-6006955264ed> in read_organize_data()
#      10
#      11     df = pd.DataFrame(columns=['image', 'label'])
# ---> 12     folders = os.listdir(file_path)
#      13     folders.sort()
#      14
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/nicolaskardous/Documents/Nick/Work/Uni 19:20/Fall/STATS 200C/Graduate Project/final_project/drive/My Drive/D100_Final_Project/20_categories_training'

# %%
starting_data.tail(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3d19d6966873> in <module>
# ----> 1 starting_data.tail(20)
#
# NameError: name 'starting_data' is not defined

# %%
starting_data.shape
# Out:
# (1501, 2)

# %%
starting_data.to_pickle('drive/My Drive/D100_Final_Project/starting_data.pkl')
